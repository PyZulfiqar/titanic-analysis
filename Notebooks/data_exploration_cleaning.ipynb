# %% [markdown]
# # Exploring and Preparing Data
# ![Titanic](../Images/overview-Titanic.webp)

# %% [markdown]
# ## Required Libraries

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# ## Load Data and check for Null and Duplicate Values

# %%
df = pd.read_csv('../Data/titanic.csv')
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0          892         0       3
# 1          893         1       3
# 2          894         0       2
# 3          895         0       3
# 4          896         1       3
#
#                                            Name     Sex   Age  SibSp  Parch  \
# 0                              Kelly, Mr. James    male  34.5      0      0
# 1              Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                     Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                              Wirz, Mr. Albert    male  27.0      0      0
# 4  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
#
#     Ticket     Fare Cabin Embarked
# 0   330911   7.8292   NaN        Q
# 1   363272   7.0000   NaN        S
# 2   240276   9.6875   NaN        Q
# 3   315154   8.6625   NaN        S
# 4  3101298  12.2875   NaN        S

# %% [markdown]
# [**Understanding Columns**](https://www.kaggle.com/datasets/brendan45774/test-file/discussion/358088)
# 1. survival - Survival (0 = No; 1 = Yes)
# 2. class - Passenger Class (1 = 1st; 2 = 2nd; 3 = 3rd)
# 3. name - Name
# 4. sex - Sex
# 5. age - Age
# 6. sibsp - Number of Siblings/Spouses Aboard
# 7. parch - Number of Parents/Children Aboard
# 8. ticket - Ticket Number
# 9. fare - Passenger Fare
# 10. cabin - Cabin
# 11. embarked - Port of Embarkation (C = Cherbourg; Q = Queenstown; S = Southampton)

# %%
df.shape
# Out:
# (418, 12)

# %%
df.dtypes
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %% [markdown]
# ## Dealing with the missing values

# %%
df.isna().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age             86
# SibSp            0
# Parch            0
# Ticket           0
# Fare             1
# Cabin          327
# Embarked         0
# dtype: int64

# %% [markdown]
# ### only 1 null fare, we'll drop it

# %%
df.dropna(subset=['Fare'], inplace=True)
df['Fare'].isna().sum()
# Out:
# 0

# %% [markdown]
# ### 20 % of our samples, have null age, let's replace them with the mean of the age col

# %%
df['Age'].isna().sum() / df.shape[0]
# Out:
# 0.20623501199040767

# %%
Cabin_col = df['Cabin']
df.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
mean_age = round(df['Age'].dropna().values.mean(), 1)
mean_age
# Out:
# 30.2

# %%
def fill_age_na_with_mean(row):
    
    return row.fillna(mean_age)

df = df.drop(['Cabin'], axis = 1).apply(fill_age_na_with_mean, axis = 1)
df ['Cabin'] = Cabin_col
df = df.reindex(columns = ['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
       'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'])
df['Age'].isna().sum()
# Out:
# 0

# %% [markdown]
# ### there are lots of missing values for cabins column
# the effect of the passengers cabin on their survival, sounds like a fun analysis, so we'll deal with this column later

# %% [markdown]
# ## check for duplicates

# %%
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# ## Dataset with no missing values and duplicates (except for cabins column)

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0            892         0       3
# 1            893         1       3
# 2            894         0       2
# 3            895         0       3
# 4            896         1       3
# ..           ...       ...     ...
# 413         1305         0       3
# 414         1306         1       1
# 415         1307         0       3
# 416         1308         0       3
# 417         1309         0       3
#
#                                              Name     Sex   Age  SibSp  Parch  \
# 0                                Kelly, Mr. James    male  34.5      0      0
# 1                Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                       Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                                Wirz, Mr. Albert    male  27.0      0      0
# 4    Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
# ..                                            ...     ...   ...    ...    ...
# 413                            Spector, Mr. Woolf    male  30.2      0      0
# 414                  Oliva y Ocana, Dona. Fermina  female  39.0      0      0
# 415                  Saether, Mr. Simon Sivertsen    male  38.5      0      0
# 416                           Ware, Mr. Frederick    male  30.2      0      0
# 417                      Peter, Master. Michael J    male  30.2      1      1
#
#                  Ticket      Fare Cabin Embarked
# 0                330911    7.8292   NaN        Q
# 1                363272    7.0000   NaN        S
# 2                240276    9.6875   NaN        Q
# 3                315154    8.6625   NaN        S
# 4               3101298   12.2875   NaN        S
# ..                  ...       ...   ...      ...
# 413           A.5. 3236    8.0500   NaN        S
# 414            PC 17758  108.9000  C105        C
# 415  SOTON/O.Q. 3101262    7.2500   NaN        S
# 416              359309    8.0500   NaN        S
# 417                2668   22.3583   NaN        C
#
# [417 rows x 12 columns]

# %%
df.isna().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age              0
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          326
# Embarked         0
# dtype: int64

# %% [markdown]
# ## check for categories and possible dummy variables

# %%
df.describe(include='all')
# Out:
#         PassengerId    Survived      Pclass              Name   Sex  \
# count    417.000000  417.000000  417.000000               417   417
# unique          NaN         NaN         NaN               417     2
# top             NaN         NaN         NaN  Kelly, Mr. James  male
# freq            NaN         NaN         NaN                 1   265
# mean    1100.635492    0.364508    2.263789               NaN   NaN
# std      120.923774    0.481870    0.842077               NaN   NaN
# min      892.000000    0.000000    1.000000               NaN   NaN
# 25%      996.000000    0.000000    1.000000               NaN   NaN
# 50%     1101.000000    0.000000    3.000000               NaN   NaN
# 75%     1205.000000    1.000000    3.000000               NaN   NaN
# max     1309.000000    1.000000    3.000000               NaN   NaN
#
#                Age       SibSp       Parch    Ticket        Fare  \
# count   417.000000  417.000000  417.000000       417  417.000000
# unique         NaN         NaN         NaN       362         NaN
# top            NaN         NaN         NaN  PC 17608         NaN
# freq           NaN         NaN         NaN         5         NaN
# mean     30.185132    0.448441    0.393285       NaN   35.627188
# std      12.562333    0.897568    0.982419       NaN   55.907576
# min       0.170000    0.000000    0.000000       NaN    0.000000
# 25%      23.000000    0.000000    0.000000       NaN    7.895800
# 50%      30.200000    0.000000    0.000000       NaN   14.454200
# 75%      35.000000    1.000000    0.000000       NaN   31.500000
# max      76.000000    8.000000    9.000000       NaN  512.329200
#
#                   Cabin Embarked
# count                91      417
# unique               76        3
# top     B57 B59 B63 B66        S
# freq                  3      269
# mean                NaN      NaN
# std                 NaN      NaN
# min                 NaN      NaN
# 25%                 NaN      NaN
# 50%                 NaN      NaN
# 75%                 NaN      NaN
# max                 NaN      NaN

# %% [markdown]
# ### Map gender to 1 and 0

# %%
df['Sex'] = df['Sex'].map({'male': 1, 'female': 0})

# %% [markdown]
# ### Create Dummy Variables for Embarked

# %%
df = pd.concat([df, pd.get_dummies(df['Embarked'])], axis=1)
df.drop(['Embarked'], axis=1, inplace=True)

# %% [markdown]
# ### check Pclass col

# %%
df['Pclass'].unique()
# Out:
# array([3, 2, 1], dtype=int64)

# %% [markdown]
# **Create dummy variables for passenger class**

# %%
df = pd.concat([df, pd.get_dummies(df['Pclass'])], axis=1)
df.drop(['Pclass'], axis=1, inplace=True)

# %%
df = df.rename(columns={1: '1st Class', 2: '2nd Class', 3: '3rd Class', 'C': 'Cherbourg', 'Q': 'Cherbourg', 'S': 'Southampton'})

# %% [markdown]
# ## Dataset with dummy variables

# %%
df
# Out:
#      PassengerId  Survived                                          Name  Sex  \
# 0            892         0                              Kelly, Mr. James    1
# 1            893         1              Wilkes, Mrs. James (Ellen Needs)    0
# 2            894         0                     Myles, Mr. Thomas Francis    1
# 3            895         0                              Wirz, Mr. Albert    1
# 4            896         1  Hirvonen, Mrs. Alexander (Helga E Lindqvist)    0
# ..           ...       ...                                           ...  ...
# 413         1305         0                            Spector, Mr. Woolf    1
# 414         1306         1                  Oliva y Ocana, Dona. Fermina    0
# 415         1307         0                  Saether, Mr. Simon Sivertsen    1
# 416         1308         0                           Ware, Mr. Frederick    1
# 417         1309         0                      Peter, Master. Michael J    1
#
#       Age  SibSp  Parch              Ticket      Fare Cabin  Cherbourg  \
# 0    34.5      0      0              330911    7.8292   NaN      False
# 1    47.0      1      0              363272    7.0000   NaN      False
# 2    62.0      0      0              240276    9.6875   NaN      False
# 3    27.0      0      0              315154    8.6625   NaN      False
# 4    22.0      1      1             3101298   12.2875   NaN      False
# ..    ...    ...    ...                 ...       ...   ...        ...
# 413  30.2      0      0           A.5. 3236    8.0500   NaN      False
# 414  39.0      0      0            PC 17758  108.9000  C105       True
# 415  38.5      0      0  SOTON/O.Q. 3101262    7.2500   NaN      False
# 416  30.2      0      0              359309    8.0500   NaN      False
# 417  30.2      1      1                2668   22.3583   NaN       True
#
#      Cherbourg  Southampton  1st Class  2nd Class  3rd Class
# 0         True        False      False      False       True
# 1        False         True      False      False       True
# 2         True        False      False       True      False
# 3        False         True      False      False       True
# 4        False         True      False      False       True
# ..         ...          ...        ...        ...        ...
# 413      False         True      False      False       True
# 414      False        False       True      False      False
# 415      False         True      False      False       True
# 416      False         True      False      False       True
# 417      False        False      False      False       True
#
# [417 rows x 16 columns]

# %% [markdown]
# ## Dropping passengerId and Name columns
# ***I don't think a person's name has anything to do with their survival, also their id isn't that useful either, or is it??***

# %%
df.drop(['PassengerId', 'Name'], axis = 1, inplace=True)

# %% [markdown]
# ## Data half way prepared

# %%
df = df.reset_index()
df.drop(['index'], axis = 1, inplace=True)
df
# Out:
#      Survived  Sex   Age  SibSp  Parch              Ticket      Fare Cabin  \
# 0           0    1  34.5      0      0              330911    7.8292   NaN
# 1           1    0  47.0      1      0              363272    7.0000   NaN
# 2           0    1  62.0      0      0              240276    9.6875   NaN
# 3           0    1  27.0      0      0              315154    8.6625   NaN
# 4           1    0  22.0      1      1             3101298   12.2875   NaN
# ..        ...  ...   ...    ...    ...                 ...       ...   ...
# 412         0    1  30.2      0      0           A.5. 3236    8.0500   NaN
# 413         1    0  39.0      0      0            PC 17758  108.9000  C105
# 414         0    1  38.5      0      0  SOTON/O.Q. 3101262    7.2500   NaN
# 415         0    1  30.2      0      0              359309    8.0500   NaN
# 416         0    1  30.2      1      1                2668   22.3583   NaN
#
#      Cherbourg  Cherbourg  Southampton  1st Class  2nd Class  3rd Class
# 0        False       True        False      False      False       True
# 1        False      False         True      False      False       True
# 2        False       True        False      False       True      False
# 3        False      False         True      False      False       True
# 4        False      False         True      False      False       True
# ..         ...        ...          ...        ...        ...        ...
# 412      False      False         True      False      False       True
# 413       True      False        False       True      False      False
# 414      False      False         True      False      False       True
# 415      False      False         True      False      False       True
# 416       True      False        False      False      False       True
#
# [417 rows x 14 columns]
